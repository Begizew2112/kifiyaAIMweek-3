# %%
import pandas as pd

# Load the data
file_path = r'C:\Users\Yibabe\Desktop\kifiyaAIMweek-3\data\insurance_text_data.csv'
df = pd.read_csv(file_path)

# Display the first few rows to understand the structure of the data
df.head()
# Out:
# C:\Users\Yibabe\AppData\Local\Temp\ipykernel_8524\357394265.py:5: DtypeWarning: Columns (32,37) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
#    UnderwrittenCoverID  PolicyID     TransactionMonth  IsVATRegistered  \
# 0               145249     12827  2015-03-01 00:00:00             True
# 1               145249     12827  2015-05-01 00:00:00             True
# 2               145249     12827  2015-07-01 00:00:00             True
# 3               145255     12827  2015-05-01 00:00:00             True
# 4               145255     12827  2015-07-01 00:00:00             True
#
#   Citizenship          LegalType Title Language                 Bank  \
# 0              Close Corporation    Mr  English  First National Bank
# 1              Close Corporation    Mr  English  First National Bank
# 2              Close Corporation    Mr  English  First National Bank
# ...

# %%
# Check for missing values in the relevant columns
print(df[['Province', 'TotalClaims']].isnull().sum())

# Drop rows with missing values in the relevant columns
df = df.dropna(subset=['Province', 'TotalClaims'])

# Optionally, check the data types
df.dtypes
# Out:
# Province       0
# TotalClaims    0
# dtype: int64
# UnderwrittenCoverID           int64
# PolicyID                      int64
# TransactionMonth             object
# IsVATRegistered                bool
# Citizenship                  object
# LegalType                    object
# Title                        object
# Language                     object
# Bank                         object
# AccountType                  object
# MaritalStatus                object
# Gender                       object
# Country                      object
# Province                     object
# PostalCode                    int64
# MainCrestaZone               object
# SubCrestaZone                object
# ItemType                     object
# mmcode                      float64
# VehicleType                  object
# RegistrationYear              int64
# make                         object
# Model                        object
# Cylinders                   float64
# ...

# %%
Select Metrics

# %%
# Calculate the average number of claims per province
province_risk = df.groupby('Province')['TotalClaims'].mean().reset_index()

# Display the average risk levels
print(province_risk)
# Out:
#         Province  TotalClaims
# 0   Eastern Cape    44.713432
# 1     Free State    43.822975
# 2        Gauteng    74.630009
# 3  KwaZulu-Natal    84.234293
# 4        Limpopo    40.927553
# 5     Mpumalanga    38.785147
# 6     North West    41.317426
# 7  Northern Cape    14.026726
# 8   Western Cape    60.831482

# %%
Perform Statistical Analysis

# %%
from scipy.stats import f_oneway

# Create lists of claims for each province
provinces = df['Province'].unique()
claims_per_province = [df[df['Province'] == prov]['TotalClaims'] for prov in provinces]

# Perform ANOVA
f_stat, p_value = f_oneway(*claims_per_province)

print("F-statistic:", f_stat)
print("P-value:", p_value)
# Out:
# F-statistic: 5.849413762407606
# P-value: 1.6782057588675903e-07

# %%
if p_value < 0.05:
    print("There are significant differences in risk levels across provinces.")
else:
    print("There are no significant differences in risk levels across provinces.")
# Out:
# There are significant differences in risk levels across provinces.
